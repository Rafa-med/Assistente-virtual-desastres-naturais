# %% [markdown]
# #INTEGRANTES
#
# -**Rafael de Medeiros Cordeiro**
#
# -**Taysir Fauzi Ali**

# %%
# !pip install openai

# %%
from openai import OpenAI

from google.colab import userdata

client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %%
Contexto0 = '''
#Desastres naturais

Terremotos
✅ Antes
Tenha um kit de emergência com água, alimentos não perecíveis, lanternas, rádio, pilhas, medicamentos e documentos.
Saiba como desligar gás, água e eletricidade da sua casa.
Identifique locais seguros: debaixo de mesas resistentes, longe de janelas, espelhos e objetos pesados.
⚠️ Durante
Dentro de casa:
Ajoelhe-se, cubra a cabeça e proteja-se debaixo de móveis fortes.
Fique longe de janelas, estantes e lâmpadas.
Fora de casa:
Vá para áreas abertas, longe de prédios, árvores e postes.
Não use elevadores!
🟢 Depois
Verifique ferimentos em você e outros.
Saia com cuidado se o prédio estiver danificado.
Evite usar telefone a menos que seja emergência.
Cuidado com réplicas (tremores secundários).
🌊 Tsunamis
✅ Antes
Se mora em áreas costeiras, saiba a rota de evacuação mais próxima.
Preste atenção a alertas oficiais e sinais naturais, como o recuo repentino do mar.
⚠️ Durante
Após um terremoto forte, vá imediatamente para áreas elevadas, mesmo sem alerta oficial.
Nunca fique na praia para ver o tsunami!
Siga rotas de evacuação e não pare para pegar coisas.
🟢 Depois
Aguarde liberação oficial para retornar.
Mantenha-se informado com rádio ou celular.
Evite áreas inundadas e cuidado com destroços e contaminação da água.
🌪️ Furacões / Ciclones / Tufões
✅ Antes
Tenha estoque de água potável e comida para vários dias.
Fixe ou guarde objetos que possam voar (móveis de jardim, telhas soltas).
Instale protetores nas janelas ou cubra-as com madeira.
Saiba onde ficam os abrigos mais próximos.
⚠️ Durante
Fique dentro de casa, longe de janelas e portas.
Vá para o cômodo mais seguro, de preferência sem janelas e no andar mais baixo.
Não saia durante a “calmaria” do olho do furacão — ele pode retornar com força.
🟢 Depois
Evite sair até autoridades confirmarem que é seguro.
Cuidado com fios elétricos caídos, postes danificados e enchentes.
Evite beber água da rede até garantir que está potável.
🧰 Dicas Gerais para Todos os Casos

Situação  Ação Relevante
📦 Kit Emergência Água, comida, rádio, lanterna, pilhas, documentos
📱 Comunicação  Tenha contatos de emergência e números úteis salvos
🏃 Evacuação  Conheça rotas seguras e abrigos oficiais
🧠 Informação Siga fontes confiáveis: Defesa Civil, apps de emergência
💬 Treinamento  Participe de simulações e oriente familiares

'''

Contexto1 = '''

#VITIMAS DIRETAS

1. Cenário Simulado
Local: Fortaleza, Ceará
Data: 15 de março, 2026
Evento: Um grande terremoto submarino de magnitude 8.5 a 200 km da costa causa deslocamento de placas tectônicas e gera um tsunami que atinge o litoral em 30 a 45 minutos.
Aviso Prévio: Emitido pela Defesa Civil e por alertas de celular em 15 minutos após o terremoto.
Altura estimada das ondas: 4 a 6 metros
Áreas afetadas: Praias, bairros costeiros, zonas ribeirinhas.
📘 2. O que é um Tsunami?
Um tsunami é uma série de ondas gigantes provocadas por perturbações submarinas (terremotos, erupções vulcânicas ou deslizamentos). Diferente de ondas normais, ele avança como uma parede de água, inundando cidades costeiras em minutos.
🚨 3. Como Saber que um Tsunami Está a Caminho
Sinal de Alerta Natural O que Significa
Tremor de terra Pode indicar terremoto submarino
Recuo rápido e incomum da maré  Água "some" repentinamente da praia
Se ele mora em prédio alto ou morro, há chances maiores de segurança
💬 4. Mensagens Úteis para Enviar (Mesmo que não haja resposta)
"Estou aqui por você. Qualquer coisa, me avise."
"Se estiver seguro, me dê um sinal. Só uma palavra já ajuda."
"Estou acompanhando tudo e buscando ajuda por aqui."
"Confie que vai dar certo. Mantenha a calma e se proteja."
Importante: mensagens curtas e objetivas aumentam a chance de envio via redes instáveis.
🚨 5. Se o Familiar Está Desaparecido
Situação  O que Fazer
Não responde há horas ou dias Registre como desaparecido nos canais oficiais
Tenha fotos e documentos em mãos  Isso ajuda nos cadastros e buscas
Cadastre no sistema de pessoas desaparecidas  Use plataformas como da Polícia Civil ou Cruz Vermelha

📄 Exemplo de Locais para Registro
Delegacia mais próxima ou delegacia online
Central da Defesa Civil do Estado
Cruz Vermelha da região
Redes de apoio como “Desaparecidos.gov” ou redes da prefeitura
🤗 6. Como Apoiar à Distância (Mesmo Sem Poder Ir Até Lá)
✅ Compartilhe informações úteis com ele (rotas de fuga, locais de abrigo)
✅ Envie dinheiro via PIX ou apps caso ele precise
✅ Organize com outros familiares ajuda futura (roupas, alimentos, hospedagem)
✅ Mantenha a calma: sua tranquilidade ajuda outros a se manterem firmes
✅ Reze, medite ou se conecte espiritualmente, se isso for importante pra você
🧳 7. Posso Ir Até Lá?
Pergunta  Resposta Sugerida
Posso ir até a cidade atingida? Não vá sem orientação da Defesa Civil. Pode haver risco e bloqueios
Tenho condições de ajudar lá? Voluntariado só com cadastro prévio (ex: Cruz Vermelha, Exército)
Posso abrigar meu familiar? Sim, mas aguarde confirmação de resgate e transporte seguro

❤️ 8. Cuidando da Sua Saúde Mental
É normal sentir:
Angústia, impotência, desespero
Raiva por não conseguir ajudar diretamente
Medo do pior
Mas você pode:
Respirar fundo e focar no que pode controlar
Conversar com outros familiares ou amigos
Evitar excesso de exposição a notícias traumáticas
Procurar apoio psicológico (CVV: 188)
📌 Resumo Rápido: 6 Passos
Tente contato por todos os meios
Busque informações oficiais
Anote dados do seu familiar (endereço, idade, foto)
Cadastre como desaparecido se necessário
Ofereça ajuda financeira e emocional
Cuide de você para poder cuidar dos outros

'''

# %%
msgs = [{'role': 'system', 'content': 'assistente virtual que seja capaz de responder, de maneira clara e empática, a perguntas relacionadas a como reagir em situações de desastres naturais.' + Contexto0}]
msgs1 = {'role': 'system', 'content': 'assistente virtual que seja capaz de responder, de maneira clara, empática, curta e objetiva, a perguntas relacionadas a como reagir em situações de desastres naturais.' + Contexto1}
msgs2 = {'role': 'system', 'content': 'assistente virtual que seja capaz de responder, de maneira clara, empática, curta e objetiva, a perguntas relacionadas a como reagir em situações de desastres naturais.' + Contexto2}
msgs3 = {'role': 'system', 'content': 'assistente virtual que seja capaz de responder, de maneira clara e empática, a perguntas relacionadas a como reagir em situações de desastres naturais.' + Contexto3}

while True:
    pergunta = input()
    questao = pergunta.upper()
    if questao == 'VITIMAS':
      msgs.append(msgs1)
      pergunta = input()
    elif questao == 'MORADORES':
      msgs.append(msgs2)
      pergunta = input()
    elif questao == 'FAMILIARES':
      msgs.append(msgs3)
      pergunta = input()

    msgs.append({'role': 'user', 'content': pergunta})
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=msgs
    )
    resposta = completion.choices[0].message.content
    print(resposta)
    msgs.append({'role': 'assistant', 'content': resposta})
